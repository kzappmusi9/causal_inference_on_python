# %% [markdown]
# # MMM on Python
# - MMM(Marketing Mix Modeling)の実践

# %%
# %pip install --upgrade pymc_marketing

# %% [markdown]
# ## 環境設定

# %%
import warnings
import arviz as az
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pymc as pm
import seaborn as sns
from pymc_marketing.mmm.transformers import geometric_adstock, logistic_saturation
from pymc_marketing.mmm.delayed_saturated_mmm import DelayedSaturatedMMM

warnings.filterwarnings("ignore")

az.style.use("arviz-darkgrid")

plt.rcParams["figure.figsize"] = (12, 7)
plt.rcParams["figure.dpi"]  = 100

# %load_ext autoreload
# %autoreload 2

# %config InlineBackend.figure_format = 'retina'
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 8
#       4 import pandas as pd
#       5 import numpy as np
#       6 import pymc as pm
#       7 import seaborn as sns
# ----> 8 from pymc_marketing.mmm.transformers import geometric_adstock, logistic_saturation
#       9 from pymc_marketing.mmm.delayed_saturated_mmm import DelayedSaturatedMMM
#      10
#      11 warnings.filterwarnings("ignore")
#
# File ~\python_training\causal_inference\.venv\Lib\site-packages\pymc_marketing\__init__.py:33
#      31 # Register SpecialPrior deserializers (LogNormalPrior, LaplacePrior, etc.)
#      32 import pymc_marketing.special_priors  # noqa: E402, F401
# ---> 33 from pymc_marketing import bass, clv, customer_choice, mmm, pie  # noqa: E402
#      34 from pymc_marketing.version import __version__  # noqa: E402
#      36 __all__ = ["__version__", "bass", "clv", "customer_choice", "mmm", "pie", "r2d2"]
#
# File ~\python_training\causal_inference\.venv\Lib\site-packages\pymc_marketing\bass\__init__.py:54
#      14 """Bass diffusion model for product adoption forecasting.
#      15
#      16 The recommended entry point is :class:`BassModel`, which wraps the model in a
#    (...)     50     idata = model.fit(data=y_sim.values)
#      51 """
#      53 from pymc_marketing.bass.data import to_bass_dataset
# ---> 54 from pymc_marketing.bass.model import BassModel, BassPriors, create_bass_model
#      55 from pymc_marketing.bass.plotting import (
#      56     plot_adoption_curve,
#      57     plot_cumulative,
#      58     plot_decomposition,
#      59     plot_peak,
#      60 )
#      62 __all__ = [
#      63     "BassModel",
#      64     "BassPriors",
#    (...)     70     "to_bass_dataset",
#      71 ]
#
# File ~\python_training\causal_inference\.venv\Lib\site-packages\pymc_marketing\bass\model.py:157
#     155 from pymc_marketing.bass import plotting
#     156 from pymc_marketing.bass.data import to_bass_dataset
# --> 157 from pymc_marketing.model_builder import ModelBuilder, SamplingMethod
#     158 from pymc_marketing.model_config import parse_model_config
#     159 from pymc_marketing.version import __version__
#
# ImportError: cannot import name 'SamplingMethod' from 'pymc_marketing.model_builder' (c:\Users\kzapp\python_training\causal_inference\.venv\Lib\site-packages\pymc_marketing\model_builder.py)

# %% [markdown]
# ## データ生成

# %%
rng:np.random.Generator = np.random.default_rng(seed=1)
