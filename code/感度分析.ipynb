# %% [markdown]
# ## ライブラリのインポート

# %%
# %pip install -q PySensemakr==0.0.8
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import sensemakr as smkr
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col

#サンプルデータの作成
np.random.seed(1)
n = 1000
DigitalAdSpend = np.random.normal(20, 5, n)
CustomerAge = np.random.randint(20, 50, n)
PrevPurchase = np.random.choice([0, 1], n)
Region = np.random.choice([1,2,3], n)

#サンプル売り上げデータの作成
SalesRevenue = 100 + 3 * DigitalAdSpend + 0.5 * CustomerAge + 2 * PrevPurchase + np.random.normal(0, 10, n)

df = pd.DataFrame({
    'SalesRevenue': SalesRevenue,
    'DigitalAdSpend': DigitalAdSpend,
    'CustomerAge': CustomerAge,
    'PrevPurchase': PrevPurchase,
    'Region': Region
})

#モデリング
reg_model = smf.ols('SalesRevenue ~ DigitalAdSpend + CustomerAge + PrevPurchase + Region', data=df)
sales_model = reg_model.fit()

# 感度分析の実行

"""解析結果の解釈
    - RV: Robustness Value
    - ここでは未観測の交絡因子が、処置効果の推定値をゼロ（パラメータ`q`=1の場合）にするために必要な強さを示す指標
    - 例えば、RV=0.5の場合、未観測の交絡因子が処置効果の推定値をゼロにするためには、処置と結果の両方に対して0.5以上の強さを持つ必要があることを意味する
    - `benchmark_covariates`として`CustomerAge`を指定しているため、RVの解釈は「未観測の交絡因子が、処置効果の推定値をゼロにするためには、CustomerAgeと同等以上の強さを持つ必要がある」ということになる
"""

sales_sense = smkr.Sensemakr(
    model=sales_model,
    treatment='DigitalAdSpend',
    benchmark_covariates=['CustomerAge'],
    kd = [1, 2, 3],
    ky = [1, 2, 3],
    q = 1,
    alpha = 0.05,
    reduce = True)

sales_sense.summary()
# Out:
# Sensitivity Analysis to Unobserved Confounding
#
# Model Formula: SalesRevenue ~ DigitalAdSpend + CustomerAge + PrevPurchase + Region
#
# Null hypothesis: q = 1 and reduce = True
#
# -- This means we are considering biases that reduce the absolute value of the current estimate.
# -- The null hypothesis deemed problematic is H0:tau = 0.0
#
# Unadjusted Estimates of ' DigitalAdSpend ':
#   Coef. estimate: 2.959
#   Standard Error: 0.066
#   t-value: 44.988
#
# Sensitivity Statistics:
#   Partial R2 of treatment with outcome: 0.67
#   Robustness Value, q = 1 : 0.735
#   Robustness Value, q = 1 alpha = 0.05 : 0.721
#
# Verbal interpretation of sensitivity statistics:
#
# -- Partial R2 of the treatment with the outcome: an extreme confounder (orthogonal to the covariates)  that explains 100% of the residual variance of the outcome, would need to explain at least 67.042 % of the residual variance of the treatment to fully account for the observed estimated effect.
#
# -- Robustness Value, q = 1 : unobserved confounders (orthogonal to the covariates) that  explain more than 73.466 % of the residual variance of both the treatment and the outcome are strong enough to bring the point estimate to 0.0 (a bias of 100.0 % of the original estimate). Conversely, unobserved confounders that do not explain more than 73.466 % of the residual variance of both the treatment and the outcome are not strong enough to bring the point estimate to 0.0 .
#
# -- Robustness Value, q = 1 , alpha = 0.05 : unobserved confounders (orthogonal to the covariates) that explain more than 72.077 % of the residual variance of both the treatment and the outcome are strong enough to bring the estimate to a range where it is no longer 'statistically different' from 0.0 (a bias of 100.0 % of the original estimate), at the significance level of alpha = 0.05 . Conversely, unobserved confounders that do not explain more than 72.077 % of the residual variance of both the treatment and the outcome are not strong enough to bring the estimate to a range where it is no longer 'statistically different' from 0.0 , at the significance level of alpha = 0.05 .
#
# Bounds on omitted variable bias:
# --The table below shows the maximum strength of unobserved confounders with association with the treatment and the outcome bounded by a multiple of the observed explanatory power of the chosen benchmark covariate(s).
#
#       bound_label    r2dz_x   r2yz_dx       treatment  adjusted_estimate  \
# 0  1x CustomerAge  0.000007  0.160547  DigitalAdSpend           2.956518
# 1  2x CustomerAge  0.000014  0.321095  DigitalAdSpend           2.954357
# 2  3x CustomerAge  0.000020  0.481642  DigitalAdSpend           2.952197
#
#    adjusted_se  adjusted_t  adjusted_lower_CI  adjusted_upper_CI
# 0     0.060286   49.041737           2.838216           3.074819
# 1     0.054215   54.492964           2.847968           3.060747
# 2     0.047373   62.317643           2.859234           3.045160
# c:\Users\kzapp\python_training\causal_inference\.venv\Lib\site-packages\sensemakr\sensitivity_statistics.py:104: RuntimeWarning: divide by zero encountered in scalar divide
#   rv_out[(fqa > 0) & (fq > 1 / f_crit)] = rvx[(fqa > 0) & (fq > 1 / f_crit)]
# c:\Users\kzapp\python_training\causal_inference\.venv\Lib\site-packages\sensemakr\sensitivity_bounds.py:242: SingularMatrixWarning: The design matrix is rank-deficient. The model parameters are not uniquely determined.
#   treatment_results = treatment_model.fit()
# c:\Users\kzapp\python_training\causal_inference\.venv\Lib\site-packages\sensemakr\sensitivity_statistics.py:177: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return (t_statistic ** 2 / (t_statistic ** 2 + dof))[0]  # extracts float
# c:\Users\kzapp\python_training\causal_inference\.venv\Lib\site-packages\sensemakr\sensitivity_statistics.py:177: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return (t_statistic ** 2 / (t_statistic ** 2 + dof))[0]  # extracts float

# %%
xxx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 xxx
#
# NameError: name 'xxx' is not defined
